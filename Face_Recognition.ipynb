# %%
# !pip install opencv-python

# %%
# !pip install cmake

# %%
# !pip install dlib

# %%
# !pip install face_recognition

# %%
# !pip install dlib==19.18.0

# %%
import cv2
import numpy as np
import face_recognition as fr

# %%
video_capture = cv2.VideoCapture(0)

# %%
file_path = ""
image = fr.load_image_file(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-67c4396c5181> in <cell line: 4>()
#       2
#       3 # Check if the file exists
# ----> 4 image = fr.load_image_file(file_path)
#
# /usr/local/lib/python3.10/dist-packages/face_recognition/api.py in load_image_file(file, mode)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: 'boy.jpg'

# %%
image_face_encoding = fr.face_encodings(image)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-51f7bfa1aa00> in <cell line: 1>()
# ----> 1 image_face_encoding = fr.face_encodings(image)[0]
#
# NameError: name 'image' is not defined

# %%
known_face_encodings = [image_face_encoding]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-de347988208a> in <cell line: 1>()
# ----> 1 known_face_encodings = [image_face_encoding]
#
# NameError: name 'image_face_encoding' is not defined

# %%
known_face_names =["Aniket"]
known_face_names =["Anubhav"]

# %%
while True:
    ret, frame = video_capture.read()
    rgb_frame =frame[:, :, ::-1]

fc_locations =fr.face_locations(rgb_frame)
fc_encodings =fr.face_encodings(rgb_frame, fc_locations)

for(top, right, bottom, left), face_encoding in zip(fc_locations, face_encodings):
    matches =fr.compare_faces(knows_face_encodings, face_encoding)

    name = "unknow"

    fc_distances = fr.face_distances(known_face_encodings, face_encoding)

    match_index = np.argmin(fc_distances)

if matches[match_index]:
    name = known_face_names[match_index]

    cv2.rectangle(frame,(left, top), (right, bottom), (0,0,255),2)
    cv2.rectangle(frame,(left, bottom - 35), (right, bottom), (0,0,255),cv2.FILLED)

    font = cv2.FONT_HERSHEY_SIMPLEX

    cv2.putText(frame, name, (left +6, bottom -6), font,1.0, (255,255,255), 1)

cv2.imshow('My face detection system', frame)

if cv2.waitkey(1) & 0xFF == ord('q'):
    break;

video_capture.release()
cv2.destoryAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-51a7c0ab4911> in <cell line: 1>()
#       1 while True:
#       2     ret, frame = video_capture.read()
# ----> 3     rgb_frame =frame[:, :, ::-1]
#       4
#       5 fc_locations =fr.face_locations(rgb_frame)
#
# TypeError: 'NoneType' object is not subscriptable
